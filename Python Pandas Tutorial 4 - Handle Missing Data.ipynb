# %%
import pandas as pd

# %%
df = pd.read_csv('Employee_Salary_with_Missing_Data.csv')

# %%
df
# Out:
#      Name   Age   Income
# 0     Ram  27.0  70000.0
# 1   Mohan  29.0  75000.0
# 2   David   NaN  78000.0
# 3  Rajesh  30.0      NaN
# 4     NaN  32.0  84000.0
# 5     NaN   NaN      NaN
# 6  Ganesh  21.0  65000.0
# 7   Suraj   NaN      NaN
# 8   Shyam -30.0  68900.0

# %%
df.isnull()
# Out:
#     Name    Age  Income
# 0  False  False   False
# 1  False  False   False
# 2  False   True   False
# 3  False  False    True
# 4   True  False   False
# 5   True   True    True
# 6  False  False   False
# 7  False   True    True
# 8  False  False   False

# %%
df.isnull().sum()
# Out:
# Name      2
# Age       3
# Income    3
# dtype: int64

# %%
df
# Out:
#      Name   Age   Income
# 0     Ram  27.0  70000.0
# 1   Mohan  29.0  75000.0
# 2   David   NaN  78000.0
# 3  Rajesh  30.0      NaN
# 4     NaN  32.0  84000.0
# 5     NaN   NaN      NaN
# 6  Ganesh  21.0  65000.0
# 7   Suraj   NaN      NaN
# 8   Shyam -30.0  68900.0

# %%
df_fillna = df.fillna(0)

# %%
df_fillna
# Out:
#      Name   Age   Income
# 0     Ram  27.0  70000.0
# 1   Mohan  29.0  75000.0
# 2   David   0.0  78000.0
# 3  Rajesh  30.0      0.0
# 4       0  32.0  84000.0
# 5       0   0.0      0.0
# 6  Ganesh  21.0  65000.0
# 7   Suraj   0.0      0.0
# 8   Shyam -30.0  68900.0

# %%
df_fillna_dict = df.fillna({'Name':'NoName', 'Age':df['Age'].max(),'Income':df['Income'].mean()})

# %%
df_fillna_dict
# Out:
#      Name   Age        Income
# 0     Ram  27.0  70000.000000
# 1   Mohan  29.0  75000.000000
# 2   David  32.0  78000.000000
# 3  Rajesh  30.0  73483.333333
# 4  NoName  32.0  84000.000000
# 5  NoName  32.0  73483.333333
# 6  Ganesh  21.0  65000.000000
# 7   Suraj  32.0  73483.333333
# 8   Shyam -30.0  68900.000000

# %%
df_dropna = df.dropna()

# %%
df_dropna
# Out:
#      Name   Age   Income
# 0     Ram  27.0  70000.0
# 1   Mohan  29.0  75000.0
# 6  Ganesh  21.0  65000.0
# 8   Shyam -30.0  68900.0

# %%
df
# Out:
#      Name   Age   Income
# 0     Ram  27.0  70000.0
# 1   Mohan  29.0  75000.0
# 2   David   NaN  78000.0
# 3  Rajesh  30.0      NaN
# 4     NaN  32.0  84000.0
# 5     NaN   NaN      NaN
# 6  Ganesh  21.0  65000.0
# 7   Suraj   NaN      NaN
# 8   Shyam -30.0  68900.0

# %%
df_dropna_allnull = df.dropna(how='all')

# %%
df_dropna_allnull
# Out:
#      Name   Age   Income
# 0     Ram  27.0  70000.0
# 1   Mohan  29.0  75000.0
# 2   David   NaN  78000.0
# 3  Rajesh  30.0      NaN
# 4     NaN  32.0  84000.0
# 6  Ganesh  21.0  65000.0
# 7   Suraj   NaN      NaN
# 8   Shyam -30.0  68900.0

# %%
df_dropna_2nulls = df.dropna(thresh=2)

# %%
df_dropna_2nulls
# Out:
#      Name   Age   Income
# 0     Ram  27.0  70000.0
# 1   Mohan  29.0  75000.0
# 2   David   NaN  78000.0
# 3  Rajesh  30.0      NaN
# 4     NaN  32.0  84000.0
# 6  Ganesh  21.0  65000.0
# 8   Shyam -30.0  68900.0

# %%
df
# Out:
#      Name   Age   Income
# 0     Ram  27.0  70000.0
# 1   Mohan  29.0  75000.0
# 2   David   NaN  78000.0
# 3  Rajesh  30.0      NaN
# 4     NaN  32.0  84000.0
# 5     NaN   NaN      NaN
# 6  Ganesh  21.0  65000.0
# 7   Suraj   NaN      NaN
# 8   Shyam -30.0  68900.0

# %%
df_replace = df.replace(-30.0, 30.0)

# %%
df_replace
# Out:
#      Name   Age   Income
# 0     Ram  27.0  70000.0
# 1   Mohan  29.0  75000.0
# 2   David   NaN  78000.0
# 3  Rajesh  30.0      NaN
# 4     NaN  32.0  84000.0
# 5     NaN   NaN      NaN
# 6  Ganesh  21.0  65000.0
# 7   Suraj   NaN      NaN
# 8   Shyam  30.0  68900.0

# %%
df_replace_age = df.replace({'Age':-30.0},30.0)

# %%
df_replace_age
# Out:
#      Name   Age   Income
# 0     Ram  27.0  70000.0
# 1   Mohan  29.0  75000.0
# 2   David   NaN  78000.0
# 3  Rajesh  30.0      NaN
# 4     NaN  32.0  84000.0
# 5     NaN   NaN      NaN
# 6  Ganesh  21.0  65000.0
# 7   Suraj   NaN      NaN
# 8   Shyam  30.0  68900.0
