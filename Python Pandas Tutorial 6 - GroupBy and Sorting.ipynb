# %%
import pandas as pd
import numpy as np

# %%
ipl_data = {'Team': ['Riders', 'Riders', 'Devils', 'Devils', 'Kings',
   'Kings', 'Kings', 'Kings', 'Riders', 'Royals', 'Royals', 'Riders'],
   'Rank': [1, 2, 2, 3, 3,4 ,1 ,1,2 , 4,1,2],
   'Year': [2014,2015,2014,2015,2014,2015,2016,2017,2016,2014,2015,2017],
   'Points':[876,789,863,673,741,812,756,788,694,701,804,690]}
df = pd.DataFrame(ipl_data)

# %%
df
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 2   Devils     2  2014     863
# 3   Devils     3  2015     673
# 4    Kings     3  2014     741
# 5    Kings     4  2015     812
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 9   Royals     4  2014     701
# 10  Royals     1  2015     804
# 11  Riders     2  2017     690

# %%
grouped = df.groupby('Team')

# %%
type(grouped)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
for name, grp in grouped:
    print(name)
    print(grp)
# Out:
# Devils
#      Team  Rank  Year  Points
# 2  Devils     2  2014     863
# 3  Devils     3  2015     673
# Kings
#     Team  Rank  Year  Points
# 4  Kings     3  2014     741
# 5  Kings     4  2015     812
# 6  Kings     1  2016     756
# 7  Kings     1  2017     788
# Riders
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 8   Riders     2  2016     694
# 11  Riders     2  2017     690
# Royals
#       Team  Rank  Year  Points
# 9   Royals     4  2014     701
# 10  Royals     1  2015     804

# %%
grouped.get_group('Kings')
# Out:
#     Team  Rank  Year  Points
# 4  Kings     3  2014     741
# 5  Kings     4  2015     812
# 6  Kings     1  2016     756
# 7  Kings     1  2017     788

# %%
grouped['Points'].agg(np.mean)
# Out:
# Team
# Devils    768.00
# Kings     774.25
# Riders    762.25
# Royals    752.50
# Name: Points, dtype: float64

# %%
df.groupby('Team')['Points'].agg(np.mean)
# Out:
# Team
# Devils    768.00
# Kings     774.25
# Riders    762.25
# Royals    752.50
# Name: Points, dtype: float64

# %%
df.groupby('Team')['Points'].agg(np.mean).sort_values()
# Out:
# Team
# Royals    752.50
# Riders    762.25
# Devils    768.00
# Kings     774.25
# Name: Points, dtype: float64

# %%
df.groupby('Team')['Points'].agg(np.mean).sort_values(ascending=False)
# Out:
# Team
# Kings     774.25
# Devils    768.00
# Riders    762.25
# Royals    752.50
# Name: Points, dtype: float64

# %%
df.groupby('Team')['Points'].agg([np.mean,np.std])
# Out:
#           mean         std
# Team
# Devils  768.00  134.350288
# Kings   774.25   31.899582
# Riders  762.25   88.567771
# Royals  752.50   72.831998

# %%
df
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 2   Devils     2  2014     863
# 3   Devils     3  2015     673
# 4    Kings     3  2014     741
# 5    Kings     4  2015     812
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 9   Royals     4  2014     701
# 10  Royals     1  2015     804
# 11  Riders     2  2017     690

# %%
df.sort_values(by='Year')
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 2   Devils     2  2014     863
# 4    Kings     3  2014     741
# 9   Royals     4  2014     701
# 1   Riders     2  2015     789
# 3   Devils     3  2015     673
# 5    Kings     4  2015     812
# 10  Royals     1  2015     804
# 6    Kings     1  2016     756
# 8   Riders     2  2016     694
# 7    Kings     1  2017     788
# 11  Riders     2  2017     690

# %%
df.sort_values(by='Year',ascending=False)
# Out:
#       Team  Rank  Year  Points
# 7    Kings     1  2017     788
# 11  Riders     2  2017     690
# 6    Kings     1  2016     756
# 8   Riders     2  2016     694
# 1   Riders     2  2015     789
# 3   Devils     3  2015     673
# 5    Kings     4  2015     812
# 10  Royals     1  2015     804
# 0   Riders     1  2014     876
# 2   Devils     2  2014     863
# 4    Kings     3  2014     741
# 9   Royals     4  2014     701

# %%
df.sort_values(by=['Year','Rank'])
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 2   Devils     2  2014     863
# 4    Kings     3  2014     741
# 9   Royals     4  2014     701
# 10  Royals     1  2015     804
# 1   Riders     2  2015     789
# 3   Devils     3  2015     673
# 5    Kings     4  2015     812
# 6    Kings     1  2016     756
# 8   Riders     2  2016     694
# 7    Kings     1  2017     788
# 11  Riders     2  2017     690

# %%
df['Year'].sort_values()
# Out:
# 0     2014
# 2     2014
# 4     2014
# 9     2014
# 1     2015
# 3     2015
# 5     2015
# 10    2015
# 6     2016
# 8     2016
# 7     2017
# 11    2017
# Name: Year, dtype: int64
